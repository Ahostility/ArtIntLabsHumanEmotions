# %% [markdown]
# <a href="https://colab.research.google.com/github/pandov/mafia/blob/video/notebooks/EmoNet_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from getpass import getpass
u = input('Username: ')
p = getpass('Password: ')
m = input('E-mail: ')
b = input('Branch: ')
# Out:
# Username: pandov
# Password: ··········
# E-mail: ipandov17@gmail.com
# Branch: video

# %%
! git config --global user.email $m
! git config --global user.name $u
! git init
! git remote add origin https://$u:$p@github.com/pandov/mafia.git
# Out:
# Initialized empty Git repository in /content/.git/

# %%
! git pull origin $b
! git checkout -b $b
# Out:
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 213 (delta 27), reused 61 (delta 22), pack-reused 135
# Receiving objects: 100% (213/213), 125.85 KiB | 715.00 KiB/s, done.
# Resolving deltas: 100% (64/64), done.
# From https://github.com/pandov/mafia
#  * branch            video      -> FETCH_HEAD
#  * [new branch]      video      -> origin/video
# Switched to a new branch 'video'

# %%
! sh colab.sh
# Out:
# ...
#      |████████████████████████████████| 337kB 6.9MB/s
# ...
#      |████████████████████████████████| 327kB 21.1MB/s
# ...
#      |████████████████████████████████| 71kB 9.1MB/s
# ...
#      |████████████████████████████████| 460kB 29.0MB/s
# ...
#      |████████████████████████████████| 276kB 21.3MB/s
# ...
#      |████████████████████████████████| 51kB 7.2MB/s
# ...
#      |████████████████████████████████| 112kB 31.5MB/s
# ...
#      |████████████████████████████████| 1.8MB 31.3MB/s
# ...
#      |████████████████████████████████| 552kB 38.2MB/s
# ...
#      |████████████████████████████████| 51kB 6.3MB/s
# ...
#      |████████████████████████████████| 235kB 42.7MB/s
# ...
#      |████████████████████████████████| 61kB 7.3MB/s
# ...
#      |████████████████████████████████| 204kB 39.2MB/s
# ...
#      |████████████████████████████████| 2.1MB 41.8MB/s
# ...
#      |████████████████████████████████| 71kB 9.1MB/s
# ...
#      |████████████████████████████████| 552kB 36.4MB/s
# ...
#      |████████████████████████████████| 2.7MB 33.5MB/s
# ...

# %%
! dvc pull stages/BIOMETRY_datamining.dvc
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
# 100% 1.40k/1.40k [00:00<00:00, 6.98kB/s]
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#
#
# 100% 1.40k/1.40k [00:00<00:00, 5.09kB/s]
#
#
#
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
# 100% 1.40k/1.40k [00:00<00:00, 6.60kB/s]
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
# 100% 1.40k/1.40k [00:00<00:00, 5.98kB/s]
#
#
#
#
#
# 100% 1.40k/1.40k [00:00<00:00, 6.93kB/s]
#
#
#
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
# 100% 1.40k/1.40k [00:00<00:00, 6.90kB/s]
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#
#
#
#   0% 0.00/1.40k [00:00<?, ?B/s]
#
#
#
#
# ...

# %%
! dvc repro -s -f stages/EmoNet_experiment1.dvc
# Out:
# Running command:
# 	python -m src.experiments.EmoNet.train --batch_size 90 --num_epochs 100 --logdir EmoNet/1 --hidden_size 256 --sample 1 --verbose --deterministic
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# 2020-05-07 12:26:07.214800: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# ...

# %%
! dvc metrics modify -t json -x best data/logs/EmoNet/1/checkpoints/_metrics.json
# Out:
# If DVC froze, see `hardlink_lock` in <man.dvc.org/config#core>

# %%
! dvc metrics show
# Out:
# WARNING: Metrics file 'data/logs/FMDepthRNN/0/checkpoints/_metrics.json' does not exist at the reference ''.
# WARNING: Metrics file 'data/logs/EmoNet/0/checkpoints/_metrics.json' does not exist at the reference ''.
# 	data/logs/EmoNet/1/checkpoints/_metrics.json: {'best': {'accuracy01': 0.9878787886012684, 'accuracy03': 0.9999999945813959, 'accuracy05': 0.9999999945813959, 'loss': 0.024832671664295383}}

# %%
! dvc push stages/EmoNet_experiment1.dvc
# Out:
#   0% 0.00/531k [00:00<?, ?B/s]
#   0% 0.00/180k [00:00<?, ?B/s]
#   0% 0.00/180k [00:00<?, ?B/s]
#
# data/logs/EmoNet/1/_base_log:   0% 0.00/110 [00:00<?, ?B/s]
#
#
# data/logs/EmoNet/1/train_log:   0% 0.00/110 [00:00<?, ?B/s]
#
#
#
# data/logs/EmoNet/1/valid_log:   0% 0.00/110 [00:00<?, ?B/s]
#
#
#
# data/logs/EmoNet/1/valid_log:   0% 0.00/110 [00:00<?, ?B/s]
#
#
#
#
#   0% 0.00/254k [00:00<?, ?B/s]
#
#
#
#
#   0% 0.00/254k [00:00<?, ?B/s]
#
#
# data/logs/EmoNet/1/train_log:   0% 0.00/110 [00:00<?, ?B/s]
#
#
#
#
#
#   0% 0.00/9.61k [00:00<?, ?B/s]
#
#
#
#
#
#   0% 0.00/9.61k [00:00<?, ?B/s]
#
#
#
#
#
#
#   0% 0.00/254k [00:00<?, ?B/s]
#
#
#
#
#
#
#   0% 0.00/254k [00:00<?, ?B/s]
#
#
#
#
#
# 100% 9.61k/9.61k [00:00<00:00, 46.0kB/s]
#
#
#
#
#
#
#
#
#
#
#
# data/logs/EmoNet/1/log.txt:   0% 0.00/27.3k [00:00<?, ?B/s]
#
#
#
#
#
# data/logs/EmoNet/1/log.txt:   0% 0.00/27.3k [00:00<?, ?B/s]
#
#
#
# data/logs/EmoNet/1/valid_log: 100% 110/110 [00:00<00:00, 478B/s]
#
#
#
#
#
#
#
#
#
# ...

# %%
! git add stages/EmoNet_experiment1.dvc
! git commit -m 'run stage'
! git push origin $b
# Out:
# [video 1aa0f93] run stage
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 796 bytes | 796.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 3 local objects.
# To https://github.com/pandov/mafia.git
#    7a5b84e..1aa0f93  video -> video
